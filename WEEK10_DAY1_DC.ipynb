# %% [markdown]
# # Daily Challenge 18/08/2025 - Precision Prompting for Control & Output Quality

# %% [markdown]
# # What you will create?
#   # You’ll design, test, and refine a prompt that performs four different control tasks in a realistic content generation workflow.
#   # You’ll work through a full prompt development cycle:
#     1.Crafting a prompt with tone, structure, format, and length control
#     2.Evaluating the output for quality and accuracy
#     3.Mitigating hallucination risks
#     4.Enhancing clarity through quoting or paraphrasing techniques

# %% [markdown]
# # What Will You Use?
#   # Concepts: advanced prompting (tone, structure, format, length), hallucination detection, paraphrasing vs. quoting
#   # Techniques: role prompting, instruction-based prompting, output constraints, iterative evaluation & revision
#   # Method: prompt development cycle (design → generate → evaluate → refine)
#   # Model: Generative AI (e.g., ChatGPT/GPT-4, Gemini, DeepSeek, …)
#   # Dataset: the provided policy paragraph on remote access security

# %% [markdown]
# # Scenario
#   # You work on the Learning & Communications Team at a global tech company.
#   # You’ve been asked to use generative AI to create employee-facing microlearning content for an internal newsletter.
#   # Your task is to turn a paragraph from a recent internal policy update into a concise and clear knowledge snippet. The original policy text is overly formal, dense, and full of jargon.

# %%
# Step 1: Craft a Prompt That Controls Output Tone, Format, and Length

# Using the following original text excerpt, write a prompt that:
    # Rewrites it in a friendly and clear tone
    # Uses bullet points to organize information
    # Paraphrases the original, avoiding direct quotations
    # Stays under 75 words total

# Input Text: Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.

# Proposed prompt : "Prompt :
  # "Rewrite the following text in a friendly and clear tone. Use bullet points to organize information. Paraphrase the message (no direct quotes)".
  # "Keep the result under 75 words.
  # "Input text: Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications."

# Comments :
  # Message dedicated to basic IT security rules.
  # Key points :
      # Use of approved VPN only
      # Never use unsecured connexion
      # Never use unprotected personal devices

# %% [markdown]
# # Prompt response :
#     # Always log in through the official secure VPN when working remotely.
#     # Never connect using public or unprotected networks.
#     # Avoid using personal devices without proper security tools to access company information.

# %%
# Step 2: Evaluate the Output
    # Once you’ve generated the response, review it using the following criteria:
      # Relevance         =>	Does the output stick to the message of the source content?     Mainly, though not clearly addressed to employees
      # Clarity	          =>  Is the message easier to understand for non-technical staff?    Not significantly
      # Structure         =>	Is the information formatted into clear bullet points?          YES
      # Tone	            =>  Is the language appropriate for internal employee communication? Partially
      # Length	          =>  Does it stay under 75 words?                                    30 Words in total, very much below the 75 words limit
      # Factual Accuracy  => Did the model make up or remove any critical security details?   NO

# %%
# Step 3: Detect and Mitigate Hallucinations
    # If the model adds extra content (e.g., new policy terms, technologies not in the input), write a revised version of your original prompt that strictly limits the model to the input only.

    # No hallucination detected in the model

# %%
# Step 4: Paraphrasing Deep Dive :

# Créer une nouvelle version du prompt pour reformuler la politique à destination d’un stagiaire junior :
    # ≤ 4 bullet points
    # Simple language, short phrases
    # Goodwilling and informative tone
    # No corporate or legal wording

# New prompt proposal :
  # "Rewrite the policy below for a junior intern audience. Use plain language and short phrases. Keep a supportive, informative tone. Output 3–4 bullet points (max 4). Avoid corporate or legal jargon. Paraphrase—no direct quotes.
  # "Input text: “Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.”

# %% [markdown]
# # New prompt response :
#     # When working remotely, always use the company VPN.
#     # Never connect on public or unprotected Wi-Fi.
#     # Only use a personal device if it has our security software installed and updated.
#     # This keeps company info and messages safe.

# %%
# Step 5 : Quote Extraction Variant
    # Sometimes, quoting is more effective than paraphrasing. Write a new prompt that extracts one direct quote from the original text that best captures the core security policy.

    # New prompt proposal :
        # Rewrite the employee policy below for an intern audience. Focus especially on the rule that all remote access must go through the approved secure VPN. Use a friendly and supportive tone. Write 3–4 short bullet points. Avoid corporate or legal jargon. Keep the total length under 75 words. Paraphrase the message, no direct quotes.
        # Input text: “Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.”

# %% [markdown]
# # New prompt response :
#     # Always connect through the company-approved secure VPN when working remotely.
#     # Never use public or unprotected Wi-Fi to access internal tools.
#     # Use only devices with our security software installed and up to date.
#     # This keeps our data and chats safe.

# %%
# When is quoting more appropriate than paraphrasing?
    # Policy/handbook pages and compliance acknowledgments where legal/disciplinary wording must remain exact.
    # Security banners/training slides highlighting the single, non-negotiable rule.
    # Disciplinary procedures: when issuing a formal warning, quote the exact rule to avoid any dispute.
    # Contracts with service providers: inserting the security clause as written ensures clear legal effect.

# When can quoting pose a risk?
    # Outdated or soon-to-change text—quoting might induce obsolete guidance.
    # Ambiguous or legalistic wording—readers may misinterpret without context.
    # Partial quotes out of context can cause ambiguity on the policy’s intent.
    # Exposure of sensitive internal phrasing in broadly shared docs.
