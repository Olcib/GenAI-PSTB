# %% [markdown]
# Challenge Description:
# Scenario: You are a data analyst working with a dataset of global weather. Your task is to analyze temperature trends and visualize the results.
#
# Tasks:
# 1. Data Preparation:
# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#
# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.
# 2. Data Analysis:
#
# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
# Calculate the annual average temperature for each city.
#
# Identify the city with the highest and lowest average temperature for the year.
# 3. Data Visualization:
#
#
#
# Possible visualization might be:
#
#
# daily
#
#
# Deliverables:
# A Jupyter Notebook containing all the code for data generation, analysis, and visualization.
# A brief report within the notebook summarizing your findings, including the city with the highest and lowest average temperatures and any interesting trends observed in the data.
#
#
# Evaluation Criteria:
# Correctness and efficiency of NumPy and Pandas code used for data manipulation.
# Effectiveness of data visualization in conveying the temperature trends.
# Clarity and conciseness of the summary report.
# Good luck!

# %%
#Tasks:
#1. Data Preparation:

import pandas as pd
import numpy as np


df = pd.read_csv("cities.csv")

df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1245 entries, 0 to 1244
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   station_id  1245 non-null   object
#  1   city_name   1244 non-null   object
#  2   country     1245 non-null   object
#  3   state       1217 non-null   object
#  4   iso2        1239 non-null   object
#  5   iso3        1245 non-null   object
#  6   latitude    1245 non-null   float64
#  7   longitude   1245 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 77.9+ KB

# %%
df.describe()

# %% [markdown]
# 1. Data Preparation:
# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#
# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.
# 2. Data Analysis:

# %%
# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
temperatures = np.random.uniform(low=-5, high=35, size=(7, 4))

print("Week temperatures :", temperatures)
# Out:
# Week temperatures : [[17.31570603 25.15411916 28.299114   22.34259669]
#  [13.1848509  30.20261918  3.87021308 17.56428047]
#  [24.30960123 21.90084998 31.13342769 32.204576  ]
#  [ 0.31936258 16.49126976  7.57073092  7.53175637]
#  [14.53091833  1.27001141 10.30615002 -3.98831899]
#  [33.63479092 31.07699411 28.24690921 17.4503749 ]
#  [13.32341854 29.47597685 21.69003761 19.52472056]]

# %%
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.

# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.

# %%
# Step 1 : Generate temperatures (10 cities x 12 months)
data = np.random.uniform(-5, 35, size=(10, 12))

# Step 2 : Cities names (index) and months (columns)
cities = [f"City_{i+1}" for i in range(10)]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# Step 3 : Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.
df = pd.DataFrame(data, index=cities, columns=months)

# Display
print(df)

# %% [markdown]
# 2. Data Analysis:
# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
# Calculate the annual average temperature for each city.
#
# Identify the city with the highest and lowest average temperature for the year.

# %%
# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).

# Yearly average calculation :
df["Yearly_average"] = df.mean(axis=1)
print(df)

# %%
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.

# city with the highest yearly average temperature
hotest_city = df["Yearly_average"].idxmax()
# city with the lowest  yearly average temperature 
coldest_city = df["Yearly_average"].idxmin()

print("hotest_city :", hotest_city)
print("coldest_city :", coldest_city)
# Out:
# hotest_city : City_3
# coldest_city : City_6

# %%
# Data visualization

# Deliverables:
    # A Jupyter Notebook containing all the code for data generation, analysis, and visualization.

import matplotlib.pyplot as plt

# Average temperature per month (column-wise mean)
monthly_avg = df[months].mean()

# Plotting
plt.figure(figsize=(12, 6))
monthly_avg.plot(marker='o')

plt.title("Average Monthly Temperature Across All Cities")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.grid(True)

# %%
# Transposition as to get months on x axis and cities as lines

# Suppose df is your DataFrame with cities as index and months as columns
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
          
df[months].T.plot(figsize=(12, 6), marker='o')

# Plot fine tuning 
plt.xticks(ticks=range(12), labels=months)  # Ensure that all months are displayed 
plt.legend(title="Cities", bbox_to_anchor=(1.05, 1), loc='upper left')  # Legend display

plt.tight_layout()
plt.show()

# %% [markdown]
# # A brief report within the notebook summarizing your findings, including the city with the highest and lowest average temperatures and any interesting trends observed in the data.
#
# CONCLUSION :
# - The city showing the hotest yearly average temperatures is : City_3
# - The city showing the coldest yearly average temperatures is : City_6
#
# - Dramatic ups and downs are seeable, sometimes from one month to the following (example : City 10 for Oct to Nov and Dec; idem for City 2 or City 7).
# - Not so many cities show rather stable yearly average temperatures. City 3 seems more in this category.
# - Comparing mean and max amplitudes for the 10 cities might help figuring out about this.
